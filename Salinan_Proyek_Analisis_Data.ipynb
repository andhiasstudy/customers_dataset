# %% [markdown]
# # Proyek Analisis Data: Customers_dataset
# - **Nama:** Andhias Abdillah Ridho
# - **Email:** cdcc001d6y1194@student.devacademy.id
# - **ID Dicoding:** CCDC001D6Y1194

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Kota mana yang memiliki jumlah pelanggan unik terbanyak dan berapa kontribusinya terhadap total pelanggan pada dataset e-commerce?
# - **Pertanyaan 2:** Bagaimana distribusi jumlah pelanggan unik di setiap state, dan state mana yang memberikan kontribusi terbesar terhadap total pelanggan?
# - ...

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from babel.numbers import format_currency
sns.set(style='dark')
# !pip install streamlit babel
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 61.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 87.7 MB/s eta 0:00:00
# ...
# Mounted at /content/drive

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load df Customer

# %%
customer_df = pd.read_csv('/content/drive/MyDrive/E-Commerce Public Dataset/customers_dataset.csv')
customer_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Identifying Customer_df problem

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customer_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
print("Jumlah duplikasi: ", customer_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customer_df.describe().T
# Out:
#                             count          mean           std     min  \
# customer_zip_code_prefix  99441.0  35137.474583  29797.938996  1003.0
#
#                               25%      50%      75%      max
# customer_zip_code_prefix  11347.0  24416.0  58900.0  99990.0

# %% [markdown]
# **Steps to Take:**
# - Melakukan Eksplorasi Data
# - Visualisasi dan tarik kesimpulan

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing Customer_df problem

# %%
customer_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
customer_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore customer_df

# %%
customer_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 13476  f1ae335df0c4b9403eedeab63a4b3ba7  7187cbe230014abac92d8af2c6f4a2dd
# 12736  7a733e972010c8be298c2e2fe705f05e  d7830d2cd796b860f29c873a109fae4b
# 21482  055d109c6027a0552d11c3b1dc8d7986  6abc999251612920bec93b3be616fa1d
# 31672  a567d00cce9a16c45c561f6c3d0d6cc8  5fc346439c64a91fa47fdad0a658488e
# 99363  bf9a4770691ff9b2ddb07f4beb77d4ad  95a3dcd03d8086e8510d9fe16f875ec7
#
#        customer_zip_code_prefix   customer_city customer_state
# 13476                     68627     paragominas             PA
# 12736                     21931  rio de janeiro             RJ
# 21482                      4455       sao paulo             SP
# 31672                     14085  ribeirao preto             SP
# 99363                     76105    firminopolis             GO

# %%
customer_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     274fa6071e5e17fe303b9748641082c8  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customer_df.customer_id.is_unique
# Out:
# True

# %%
customer_df.customer_id.duplicated
# Out:
# <bound method Series.duplicated of 0        06b8999e2fba1a1fbc88172c00ba8bc7
# 1        18955e83d337fd6b2def6b18a428ac77
# 2        4e7b3e00288586ebd08712fdd0374a03
# 3        b2b6027bc5c5109e529d4dc6358b12c3
# 4        4f2d8ab171c80ec8364f7c12e35b23ad
#                        ...
# 99436    17ddf5dd5d51696bb3d7c6291687be6f
# 99437    e7b71a9017aa05c9a7fd292d714858e8
# 99438    5e28dfe12db7fb50a4b2f691faecea5e
# 99439    56b18e2166679b8a959d72dd06da27f9
# 99440    274fa6071e5e17fe303b9748641082c8
# Name: customer_id, Length: 99441, dtype: object>

# %%
customer_df.groupby(by="customer_state").agg({
    "customer_id": "nunique",
    "customer_unique_id": "nunique",
    "customer_city": "nunique"
}).T
# Out:
# customer_state      AC   AL   AM  AP    BA    CE    DF    ES    GO   MA  ...  \
# customer_id         81  413  148  68  3380  1336  2140  2033  2020  747  ...
# customer_unique_id  77  401  143  67  3277  1313  2075  1964  1952  726  ...
# customer_city        8   68    5   6   353   161     6    95   178  122  ...
#
# customer_state        PR     RJ   RN   RO  RR    RS    SC   SE     SP   TO
# customer_id         5045  12852  485  253  46  5466  3637  350  41746  280
# customer_unique_id  4882  12384  474  240  45  5277  3534  342  40302  273
# customer_city        364    149   90   35   2   379   240   46    629   56
#
# [3 rows x 27 columns]

# %%
customer_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# agisse                1
# vieiras               1
# bertopolis            1
# abadiania             1
# xexeu                 1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Kota mana yang memiliki jumlah pelanggan unik terbanyak pada dataset tahun 2025, dan berapa jumlahnya?

# %%
top10 = (
    customer_df.groupby("customer_city")["customer_unique_id"]
    .nunique()
    .sort_values(ascending=False)
    .head(10)
)

plt.figure()
top10.plot(kind='bar')

plt.title("Top 10 Kota dengan Jumlah Pelanggan Terbanyak (2025)")
plt.xlabel("Kota")
plt.ylabel("Jumlah Pelanggan Unik")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Pertanyaan 2: Bagaimana distribusi jumlah pelanggan unik di setiap state, dan state mana yang memberikan kontribusi terbesar terhadap total pelanggan?

# %%
state_dist = (
    customer_df.groupby("customer_state")["customer_unique_id"]
    .nunique()
    .reset_index(name="jumlah_pelanggan")
    .sort_values(by="jumlah_pelanggan", ascending=False)
)

plt.figure()
sns.barplot(data=state_dist, x="customer_state", y="jumlah_pelanggan")

plt.title("Distribusi Pelanggan per State (2025)")
plt.xlabel("State")
plt.ylabel("Jumlah Pelanggan Unik")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - **Conclusion pertanyaan 1:** Terdapat beberapa kota yang memiliki jumlah pelanggan jauh lebih tinggi dibandingkan kota lainnya. Kota dengan jumlah pelanggan unik terbanyak menunjukkan adanya konsentrasi pasar yang kuat di wilayah tersebut.
# - **Conclusion pertanyaan 2:** Distribusi pelanggan antar state tidak merata, di mana beberapa state memiliki kontribusi pelanggan yang jauh lebih besar dibandingkan state lainnya.
# - ...

# %% [markdown]
# **Rekomendasi Action Item:**
# - Memprioritaskan kota dengan pelanggan terbanyak sebagai target utama pemasaran dan Meningkatkan promosi, layanan, atau kampanye di kota tersebut untuk memaksimalkan revenue.
# - Untuk memaksimalkan pasar, dapat dilakukan dengan memfokuskan pada state dengan kontribusi terbesar untuk optimasi strategi bisnis, mengembangkan strategi ekspansi di state dengan pelanggan rendah untuk memperluas pasar
